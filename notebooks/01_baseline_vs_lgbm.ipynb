# %% [markdown]
# # Phase 1: Baseline vs LightGBM Projection Model
#
# This notebook documents the modeling story for the Phase 1 player projection model.
#
# ## Contents
#
# 1. EDA: feature distributions and target variable analysis
# 2. Baseline models: naive last-game, trailing-7-day mean, season-to-date mean
# 3. M1 Ridge regression (floor)
# 4. M2 LightGBM quantile regression (uncalibrated intervals)
# 5. M3 CQR + ACI (calibrated intervals)
# 6. Comparison: RMSE, MAE, Spearman rho
# 7. Calibration diagnostics: reliability diagram, coverage analysis
# 8. Slice analysis: by position, playing time, veteran/rookie status
# 9. Feature importance
# 10. Conclusions and selection
#
# **Status:** Skeleton. To be filled by modeler subagent after Step 6 (Test touch).
#
# **Companion docs:**
# - `packages/ml/evaluation/validation_protocol.md`
# - `docs/model_bakeoff.md`
# - `docs/feature_plan.md`

# %%
# To be implemented by modeler subagent
